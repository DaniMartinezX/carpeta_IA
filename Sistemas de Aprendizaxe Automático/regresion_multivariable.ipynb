# %% [markdown]
# ## ¿Qué es Scikit-Learn?
# Es una biblioteca de Python que proporciona acceso a versiones eficaces de muchos algoritmos comunes. También proporciona una API propia y estandarizada.

# %% [markdown]
# > Para la instalación de la biblioteca:<br>**%conda install conda-forge::scikit-learn**

# %% [markdown]
# 1) Descomprimido del archivo comprimido

# %%
import tarfile
fichero = "archivos_comprimidos/housing.tgz"

f = tarfile.open(fichero)
f.extractall(path="archivos_comprimidos/")
f.close()

# %% [markdown]
# 2) Lectura del fichero CSV

# %%
import pandas as pd
archivo = "archivos_comprimidos/housing.csv"
datos = pd.read_csv(archivo)

# %%
datos.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
len(datos)
# Out:
# 20640

# %% [markdown]
# ¿Cuántos valores distintos hay de la columna "ocean_priximity"?

# %%
datos["ocean_proximity"].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
datos.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %% [markdown]
# ### Histogramas
# - **bins** -> Divisiones en los histogramas
# <br>
# - **figsize** -> Para cambiar el tamaño de las figuras y se vea más claro

# %%
datos.hist(bins=50,figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %% [markdown]
# - **alpha**: Tranparencia de los puntos
# - **s**: Para el tamaño de los puntos según los datos de una columna que se le proponga.
# - **c**: Para el color de los puntos según los datos de una columna que se le proponga

# %%
datos.plot(kind="scatter", 
           x= "longitude", 
           y = "latitude", 
           alpha = 0.2,
           s=datos["population"]/100,
           c="median_house_value")   # Se divide entre 100 para que no salgan muy grandes
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
# !pip install pillow
# !pip install basemap
# !pip install basemap-data-hires
# Out:
# Requirement already satisfied: pillow in c:\users\daniel.martinezcarre\appdata\local\miniconda3\envs\ia\lib\site-packages (10.0.1)
# Collecting basemap
#   Downloading basemap-1.4.0-cp38-cp38-win_amd64.whl.metadata (9.3 kB)
# Collecting basemap-data<1.4,>=1.3.2 (from basemap)
#   Downloading basemap_data-1.3.2-py2.py3-none-any.whl (30.5 MB)
#      ---------------------------------------- 0.0/30.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/30.5 MB ? eta -:--:--
#      ---------------------------------------- 0.2/30.5 MB 1.8 MB/s eta 0:00:17
#      - -------------------------------------- 1.0/30.5 MB 7.8 MB/s eta 0:00:04
#      -- ------------------------------------- 1.9/30.5 MB 10.8 MB/s eta 0:00:03
#      --- ------------------------------------ 2.7/30.5 MB 12.2 MB/s eta 0:00:03
#      ---- ----------------------------------- 3.4/30.5 MB 12.9 MB/s eta 0:00:03
#      ----- ---------------------------------- 4.3/30.5 MB 14.3 MB/s eta 0:00:02
#      ------ --------------------------------- 5.2/30.5 MB 14.4 MB/s eta 0:00:02
#      ------- -------------------------------- 6.0/30.5 MB 15.4 MB/s eta 0:00:02
#      --------- ------------------------------ 7.1/30.5 MB 15.6 MB/s eta 0:00:02
#      ---------- ----------------------------- 8.0/30.5 MB 16.0 MB/s eta 0:00:02
#      ----------- ---------------------------- 8.9/30.5 MB 16.3 MB/s eta 0:00:02
#      ------------ --------------------------- 9.8/30.5 MB 16.4 MB/s eta 0:00:02
#      ------------- ------------------------- 10.6/30.5 MB 18.7 MB/s eta 0:00:02
#      -------------- ------------------------ 11.5/30.5 MB 18.7 MB/s eta 0:00:02
#      ---------------- ---------------------- 12.6/30.5 MB 18.7 MB/s eta 0:00:01
#      ----------------- --------------------- 13.7/30.5 MB 18.7 MB/s eta 0:00:01
#      ------------------ -------------------- 14.6/30.5 MB 18.7 MB/s eta 0:00:01
#      ------------------- ------------------- 15.5/30.5 MB 18.7 MB/s eta 0:00:01
#      -------------------- ------------------ 16.4/30.5 MB 18.7 MB/s eta 0:00:01
#      --------------------- ----------------- 17.2/30.5 MB 18.7 MB/s eta 0:00:01
#      ----------------------- --------------- 18.1/30.5 MB 18.7 MB/s eta 0:00:01
#      ------------------------ -------------- 19.0/30.5 MB 18.7 MB/s eta 0:00:01
#      ------------------------- ------------- 19.8/30.5 MB 18.7 MB/s eta 0:00:01
#      -------------------------- ------------ 20.5/30.5 MB 18.7 MB/s eta 0:00:01
#      --------------------------- ----------- 21.6/30.5 MB 18.7 MB/s eta 0:00:01
#      ---------------------------- ---------- 22.5/30.5 MB 18.7 MB/s eta 0:00:01
#      ------------------------------ -------- 23.5/30.5 MB 18.7 MB/s eta 0:00:01
#      ------------------------------- ------- 24.4/30.5 MB 18.7 MB/s eta 0:00:01
#      -------------------------------- ------ 25.3/30.5 MB 18.7 MB/s eta 0:00:01
#      --------------------------------- ----- 26.2/30.5 MB 18.7 MB/s eta 0:00:01
#      ---------------------------------- ---- 27.0/30.5 MB 18.7 MB/s eta 0:00:01
#      ----------------------------------- --- 27.9/30.5 MB 18.7 MB/s eta 0:00:01
#      ------------------------------------ -- 28.7/30.5 MB 18.2 MB/s eta 0:00:01
#      ------------------------------------- - 29.5/30.5 MB 18.7 MB/s eta 0:00:01
#      --------------------------------------  30.3/30.5 MB 18.2 MB/s eta 0:00:01
#      --------------------------------------  30.5/30.5 MB 18.7 MB/s eta 0:00:01
#      --------------------------------------  30.5/30.5 MB 18.7 MB/s eta 0:00:01
#      --------------------------------------  30.5/30.5 MB 18.7 MB/s eta 0:00:01
#      --------------------------------------- 30.5/30.5 MB 13.9 MB/s eta 0:00:00
# Collecting pyshp<2.4,>=1.2 (from basemap)
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      ---------------------------------------- 0.0/46.5 kB ? eta -:--:--
#      ---------------------------------------- 46.5/46.5 kB ? eta 0:00:00
# Requirement already satisfied: matplotlib<3.9,>=1.5 in c:\users\daniel.martinezcarre\appdata\local\miniconda3\envs\ia\lib\site-packages (from basemap) (3.7.2)
# Collecting pyproj<3.7.0,>=1.9.3 (from basemap)
#   Downloading pyproj-3.5.0-cp38-cp38-win_amd64.whl (5.1 MB)
#      ---------------------------------------- 0.0/5.1 MB ? eta -:--:--
#      ---------- ----------------------------- 1.4/5.1 MB 29.2 MB/s eta 0:00:01
#      ------------------------ --------------- 3.2/5.1 MB 33.9 MB/s eta 0:00:01
#      ------------------------------------- -- 4.8/5.1 MB 34.1 MB/s eta 0:00:01
#      ---------------------------------------- 5.1/5.1 MB 27.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging<24.0,>=16.0 in c:\users\daniel.martinezcarre\appdata\local\miniconda3\envs\ia\lib\site-packages (from basemap) (23.2)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\daniel.martinezcarre\appdata\local\miniconda3\envs\ia\lib\site-packages (from basemap) (1.24.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\daniel.martinezcarre\appdata\local\miniconda3\envs\ia\lib\site-packages (from matplotlib<3.9,>=1.5->basemap) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\daniel.martinezcarre\appdata\local\miniconda3\envs\ia\lib\site-packages (from matplotlib<3.9,>=1.5->basemap) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\daniel.martinezcarre\appdata\local\miniconda3\envs\ia\lib\site-packages (from matplotlib<3.9,>=1.5->basemap) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\daniel.martinezcarre\appdata\local\miniconda3\envs\ia\lib\site-packages (from matplotlib<3.9,>=1.5->basemap) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\daniel.martinezcarre\appdata\local\miniconda3\envs\ia\lib\site-packages (from matplotlib<3.9,>=1.5->basemap) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\daniel.martinezcarre\appdata\local\miniconda3\envs\ia\lib\site-packages (from matplotlib<3.9,>=1.5->basemap) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\daniel.martinezcarre\appdata\local\miniconda3\envs\ia\lib\site-packages (from matplotlib<3.9,>=1.5->basemap) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\daniel.martinezcarre\appdata\local\miniconda3\envs\ia\lib\site-packages (from matplotlib<3.9,>=1.5->basemap) (6.1.0)
# Requirement already satisfied: certifi in c:\users\daniel.martinezcarre\appdata\local\miniconda3\envs\ia\lib\site-packages (from pyproj<3.7.0,>=1.9.3->basemap) (2023.11.17)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\daniel.martinezcarre\appdata\local\miniconda3\envs\ia\lib\site-packages (from importlib-resources>=3.2.0->matplotlib<3.9,>=1.5->basemap) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\daniel.martinezcarre\appdata\local\miniconda3\envs\ia\lib\site-packages (from python-dateutil>=2.7->matplotlib<3.9,>=1.5->basemap) (1.16.0)
# Downloading basemap-1.4.0-cp38-cp38-win_amd64.whl (507 kB)
#    ---------------------------------------- 0.0/507.6 kB ? eta -:--:--
#    --------------------------------------- 507.6/507.6 kB 31.1 MB/s eta 0:00:00
# Installing collected packages: pyshp, pyproj, basemap-data, basemap
# Successfully installed basemap-1.4.0 basemap-data-1.3.2 pyproj-3.5.0 pyshp-2.3.1
# Collecting basemap-data-hires
#   Downloading basemap_data_hires-1.3.2-py2.py3-none-any.whl (91.1 MB)
#      ---------------------------------------- 0.0/91.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/91.1 MB ? eta -:--:--
#      --------------------------------------- 0.0/91.1 MB 660.6 kB/s eta 0:02:18
#      ---------------------------------------- 0.2/91.1 MB 1.7 MB/s eta 0:00:53
#      ---------------------------------------- 0.7/91.1 MB 5.2 MB/s eta 0:00:18
#       --------------------------------------- 1.3/91.1 MB 6.8 MB/s eta 0:00:14
#       --------------------------------------- 2.1/91.1 MB 8.8 MB/s eta 0:00:11
#      - -------------------------------------- 3.0/91.1 MB 10.5 MB/s eta 0:00:09
#      - -------------------------------------- 3.9/91.1 MB 11.8 MB/s eta 0:00:08
#      -- ------------------------------------- 4.7/91.1 MB 12.5 MB/s eta 0:00:07
#      -- ------------------------------------- 5.6/91.1 MB 13.3 MB/s eta 0:00:07
#      -- ------------------------------------- 6.6/91.1 MB 14.0 MB/s eta 0:00:07
#      --- ------------------------------------ 7.6/91.1 MB 14.6 MB/s eta 0:00:06
#      --- ------------------------------------ 8.5/91.1 MB 15.1 MB/s eta 0:00:06
#      ---- ----------------------------------- 9.3/91.1 MB 15.3 MB/s eta 0:00:06
#      ---- ---------------------------------- 10.3/91.1 MB 17.7 MB/s eta 0:00:05
#      ---- ---------------------------------- 11.3/91.1 MB 18.7 MB/s eta 0:00:05
#      ----- --------------------------------- 12.1/91.1 MB 19.8 MB/s eta 0:00:04
#      ----- --------------------------------- 13.0/91.1 MB 19.3 MB/s eta 0:00:05
#      ----- --------------------------------- 13.9/91.1 MB 19.8 MB/s eta 0:00:04
#      ------ -------------------------------- 15.1/91.1 MB 20.5 MB/s eta 0:00:04
#      ------ -------------------------------- 16.0/91.1 MB 20.5 MB/s eta 0:00:04
#      ------- ------------------------------- 17.0/91.1 MB 20.5 MB/s eta 0:00:04
#      ------- ------------------------------- 17.9/91.1 MB 20.5 MB/s eta 0:00:04
#      -------- ------------------------------ 18.9/91.1 MB 19.8 MB/s eta 0:00:04
#      -------- ------------------------------ 19.8/91.1 MB 19.8 MB/s eta 0:00:04
#      -------- ------------------------------ 20.8/91.1 MB 19.9 MB/s eta 0:00:04
#      --------- ----------------------------- 21.8/91.1 MB 19.9 MB/s eta 0:00:04
#      --------- ----------------------------- 22.7/91.1 MB 19.9 MB/s eta 0:00:04
#      ---------- ---------------------------- 23.6/91.1 MB 19.8 MB/s eta 0:00:04
#      ---------- ---------------------------- 24.6/91.1 MB 19.8 MB/s eta 0:00:04
#      ---------- ---------------------------- 25.5/91.1 MB 19.8 MB/s eta 0:00:04
#      ----------- --------------------------- 26.4/91.1 MB 19.8 MB/s eta 0:00:04
#      ----------- --------------------------- 27.1/91.1 MB 19.8 MB/s eta 0:00:04
#      ----------- --------------------------- 28.0/91.1 MB 19.8 MB/s eta 0:00:04
#      ------------ -------------------------- 29.0/91.1 MB 19.8 MB/s eta 0:00:04
#      ------------ -------------------------- 29.9/91.1 MB 19.3 MB/s eta 0:00:04
#      ------------- ------------------------- 30.8/91.1 MB 19.3 MB/s eta 0:00:04
#      ------------- ------------------------- 32.0/91.1 MB 19.8 MB/s eta 0:00:03
#      -------------- ------------------------ 32.8/91.1 MB 19.3 MB/s eta 0:00:04
#      -------------- ------------------------ 33.7/91.1 MB 19.2 MB/s eta 0:00:03
#      -------------- ------------------------ 34.6/91.1 MB 19.2 MB/s eta 0:00:03
#      --------------- ----------------------- 35.6/91.1 MB 19.3 MB/s eta 0:00:03
#      --------------- ----------------------- 36.5/91.1 MB 19.3 MB/s eta 0:00:03
#      ---------------- ---------------------- 37.4/91.1 MB 19.8 MB/s eta 0:00:03
#      ---------------- ---------------------- 38.5/91.1 MB 20.5 MB/s eta 0:00:03
#      ---------------- ---------------------- 39.4/91.1 MB 20.5 MB/s eta 0:00:03
#      ----------------- --------------------- 40.3/91.1 MB 19.8 MB/s eta 0:00:03
#      ----------------- --------------------- 41.2/91.1 MB 19.8 MB/s eta 0:00:03
#      ------------------ -------------------- 42.2/91.1 MB 19.8 MB/s eta 0:00:03
#      ------------------ -------------------- 43.2/91.1 MB 20.5 MB/s eta 0:00:03
#      ------------------ -------------------- 44.1/91.1 MB 19.9 MB/s eta 0:00:03
#      ------------------- ------------------- 45.0/91.1 MB 19.9 MB/s eta 0:00:03
#      ------------------- ------------------- 46.0/91.1 MB 19.8 MB/s eta 0:00:03
#      -------------------- ------------------ 46.9/91.1 MB 19.8 MB/s eta 0:00:03
#      -------------------- ------------------ 47.8/91.1 MB 19.8 MB/s eta 0:00:03
#      -------------------- ------------------ 48.8/91.1 MB 19.8 MB/s eta 0:00:03
#      --------------------- ----------------- 49.8/91.1 MB 20.5 MB/s eta 0:00:03
#      --------------------- ----------------- 50.6/91.1 MB 19.9 MB/s eta 0:00:03
#      ---------------------- ---------------- 51.5/91.1 MB 19.9 MB/s eta 0:00:02
#      ---------------------- ---------------- 52.5/91.1 MB 19.9 MB/s eta 0:00:02
#      ---------------------- ---------------- 53.5/91.1 MB 19.8 MB/s eta 0:00:02
#      ----------------------- --------------- 54.4/91.1 MB 19.8 MB/s eta 0:00:02
#      ----------------------- --------------- 55.2/91.1 MB 20.5 MB/s eta 0:00:02
#      ------------------------ -------------- 56.4/91.1 MB 20.5 MB/s eta 0:00:02
#      ------------------------ -------------- 57.3/91.1 MB 19.8 MB/s eta 0:00:02
#      ------------------------ -------------- 58.2/91.1 MB 19.9 MB/s eta 0:00:02
#      ------------------------- ------------- 59.1/91.1 MB 19.9 MB/s eta 0:00:02
#      ------------------------- ------------- 60.0/91.1 MB 19.9 MB/s eta 0:00:02
#      -------------------------- ------------ 60.8/91.1 MB 20.5 MB/s eta 0:00:02
#      -------------------------- ------------ 61.7/91.1 MB 20.5 MB/s eta 0:00:02
#      -------------------------- ------------ 62.6/91.1 MB 19.8 MB/s eta 0:00:02
#      --------------------------- ----------- 63.3/91.1 MB 19.2 MB/s eta 0:00:02
#      --------------------------- ----------- 63.9/91.1 MB 18.7 MB/s eta 0:00:02
#      --------------------------- ----------- 64.6/91.1 MB 18.2 MB/s eta 0:00:02
#      --------------------------- ----------- 65.3/91.1 MB 17.7 MB/s eta 0:00:02
#      ---------------------------- ---------- 66.0/91.1 MB 17.2 MB/s eta 0:00:02
#      ---------------------------- ---------- 66.7/91.1 MB 17.3 MB/s eta 0:00:02
#      ---------------------------- ---------- 67.4/91.1 MB 16.8 MB/s eta 0:00:02
#      ----------------------------- --------- 68.2/91.1 MB 16.4 MB/s eta 0:00:02
#      ----------------------------- --------- 69.0/91.1 MB 16.4 MB/s eta 0:00:02
#      ----------------------------- --------- 69.7/91.1 MB 16.0 MB/s eta 0:00:02
#      ------------------------------ -------- 70.4/91.1 MB 15.6 MB/s eta 0:00:02
#      ------------------------------ -------- 71.2/91.1 MB 15.6 MB/s eta 0:00:02
#      ------------------------------ -------- 72.0/91.1 MB 15.2 MB/s eta 0:00:02
#      ------------------------------- ------- 72.7/91.1 MB 16.0 MB/s eta 0:00:02
#      ------------------------------- ------- 73.5/91.1 MB 16.0 MB/s eta 0:00:02
#      ------------------------------- ------- 74.4/91.1 MB 16.0 MB/s eta 0:00:02
#      -------------------------------- ------ 75.2/91.1 MB 16.0 MB/s eta 0:00:01
#      -------------------------------- ------ 76.0/91.1 MB 16.4 MB/s eta 0:00:01
#      -------------------------------- ------ 76.9/91.1 MB 16.4 MB/s eta 0:00:01
#      --------------------------------- ----- 77.7/91.1 MB 16.8 MB/s eta 0:00:01
#      --------------------------------- ----- 78.5/91.1 MB 16.8 MB/s eta 0:00:01
#      ---------------------------------- ---- 79.4/91.1 MB 17.2 MB/s eta 0:00:01
#      ---------------------------------- ---- 80.3/91.1 MB 17.2 MB/s eta 0:00:01
#      ---------------------------------- ---- 81.1/91.1 MB 18.2 MB/s eta 0:00:01
#      ----------------------------------- --- 82.0/91.1 MB 17.7 MB/s eta 0:00:01
#      ----------------------------------- --- 82.9/91.1 MB 18.2 MB/s eta 0:00:01
#      ----------------------------------- --- 83.4/91.1 MB 17.7 MB/s eta 0:00:01
#      ------------------------------------ -- 84.3/91.1 MB 17.3 MB/s eta 0:00:01
#      ------------------------------------ -- 84.9/91.1 MB 17.2 MB/s eta 0:00:01
#      ------------------------------------ -- 85.6/91.1 MB 16.8 MB/s eta 0:00:01
#      ------------------------------------- - 86.4/91.1 MB 16.4 MB/s eta 0:00:01
#      ------------------------------------- - 87.1/91.1 MB 16.4 MB/s eta 0:00:01
#      ------------------------------------- - 87.7/91.1 MB 16.0 MB/s eta 0:00:01
#      ------------------------------------- - 88.4/91.1 MB 16.0 MB/s eta 0:00:01
#      --------------------------------------  89.1/91.1 MB 15.6 MB/s eta 0:00:01
#      --------------------------------------  89.8/91.1 MB 15.6 MB/s eta 0:00:01
#      --------------------------------------  90.5/91.1 MB 15.2 MB/s eta 0:00:01
#      --------------------------------------  91.1/91.1 MB 15.2 MB/s eta 0:00:01
#      --------------------------------------  91.1/91.1 MB 15.2 MB/s eta 0:00:01
#      --------------------------------------  91.1/91.1 MB 15.2 MB/s eta 0:00:01
#      --------------------------------------  91.1/91.1 MB 15.2 MB/s eta 0:00:01
#      --------------------------------------  91.1/91.1 MB 15.2 MB/s eta 0:00:01
#      --------------------------------------  91.1/91.1 MB 15.2 MB/s eta 0:00:01
#      --------------------------------------  91.1/91.1 MB 15.2 MB/s eta 0:00:01
#      --------------------------------------- 91.1/91.1 MB 10.2 MB/s eta 0:00:00
# Installing collected packages: basemap-data-hires
# Successfully installed basemap-data-hires-1.3.2

# %% [markdown]
# Sobreponer los puntos encima del mapa:

# %%
import matplotlib.pyplot as plt
import mpl_toolkits
from mpl_toolkits.basemap import Basemap

m = Basemap(projection='lcc',
            resolution='h',
            lat_0=37.5,
            lon_0=-119,
            width=1E6,
            height=1.2E6)

m.shadedrelief()
m.drawcoastlines(color='gray')
m.drawcountries(color='gray')
m.drawstates(color='gray')

m.scatter( datos["longitude"], datos["latitude"],
           alpha=0.2,
           latlon=True,
           s=datos["population"]/100,)

x, y = m(-118.243683, 34.052235)
plt.text(x, y, 'Los Ángeles', fontsize=12, bbox=dict(facecolor="white", alpha=0.75));

x, y = m(-122.431297, 37.773972)
plt.text(x, y, 'San Francisco', fontsize=12, bbox=dict(facecolor="white", alpha=0.75));
