# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import pylab
pylab.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
# image = cv.imread('pedriño.png')
# cv.imshow('img', image)
# cv.waitKey(0)
path_image = "C:\\Users\\daniel.martinezcarre\\Desktop\\Repositorios\\ia_repositorio\\Programacion de IA\\tirmestre_2\\pedrinho.png"
src = cv.imread(path_image)
plt.imshow(src)

# %%
src.shape
src.size
src.dtype
# Out:
# dtype('uint8')

# %%
b, g, r = cv.split(src)
fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
fig.suptitle("Canales RGB")
ax1.imshow(r, cmap= "gray", vmin=0, vmax=255)
ax2.imshow(g, cmap= "gray", vmin=0, vmax=255)
ax3.imshow(b, cmap= "gray", vmin=0, vmax=255)

# %%
merged = cv.merge([r,g,b])
plt.imshow(merged)

# %%
src = cv.cvtColor(src, cv.COLOR_BGR2HSV)
#h,s,v = cv.split(src)
h = src[:, :, 0]
s = src[:, :, 1]
v = src[:, :, 2]
fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
fig.suptitle("Canales HSV")
ax1.imshow(h, cmap="gray", vmin=0, vmax=255)
ax1.set_title("H(tono)")
ax2.imshow(s, cmap="gray", vmin=0, vmax=255)
ax2.set_title("S(aturación)")
ax3.imshow(v, cmap="gray", vmin=0, vmax=255)
ax3.set_title("V(alor)")
print(f"H min: {h.min()}  H max: {h.max()}  H media: {h.mean()}")
print(f"S min: {s.min()}  S max: {h.max()}  H media: {h.mean()}")
print(f"H min: {h.min()}  H max: {h.max()}  H media: {h.mean()}")
# Out:
# H min: 0  H max: 179  H media: 94.47154791666667
# S min: 0  S max: 179  H media: 94.47154791666667
# H min: 0  H max: 179  H media: 94.47154791666667

# %%
src = cv.imread(path_image)
src = cv.cvtColor(src, cv.COLOR_BGR2RGB)
plt.imshow(src)

#linea blanca a la altura de 100
for i in range(src.shape[1]):
  src[100, i] = [255, 255, 255]

#linea negra vertical en 50
src[:, 50, :] = [0,0,0]

# Zona resaltada en rojo
src[330:370, 500:600, 0] = np.full((40, 100), 200, dtype=np.uint8)
plt.imshow(src)

# %%
boca = src[330:370, 500:600]
plt.imshow(boca)

# %%
src = cv.imread(path_image)
src = cv.cvtColor(src, cv.COLOR_BGR2GRAY)

min, max, minloc, maxloc = cv.minMaxLoc(src)
print(f"min: {min} en {minloc} max: {max} in {maxloc}")

means, stddev = cv.meanStdDev(src)
print((f"Media: {means} DesStd: {stddev}"))

#bianrizando
src[np.where(src < means)] = 0
src[np.where(src >= means)] = 255

plt.imshow(src, cmap="gray")
# Out:
# min: 0.0 en (573, 447) max: 255.0 in (470, 129)
# Media: [[168.69757361]] DesStd: [[80.45243926]]
